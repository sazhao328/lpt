# %%
import torch
import math


dtype = torch.float
device = torch.device('cpu')

x = torch.linspace(-math.pi, math.pi, 2000,device=device,dtype=dtype)
y = torch.sin(x)


a = torch.randn((),device=device,dtype = dtype, requires_grad=True)
b = torch.randn((),device=device,dtype = dtype, requires_grad=True)
c = torch.randn((),device=device,dtype = dtype, requires_grad=True)
d = torch.randn((),device=device,dtype = dtype, requires_grad=True)

learning_rate = 1e-6
for t in range(20000):
    y_pred = a + b * x + c * x ** 2 + d * x ** 3

    loss = (y_pred - y).pow(2).sum()
    if t % 100 == 99:
        print(t, loss)
    loss.backward()
    with torch.no_grad():
        a -= learning_rate * a.grad
        b -= learning_rate * b.grad
        c -= learning_rate * c.grad
        d -= learning_rate * d.grad

        a.grad = None
        b.grad = None
        c.grad = None
        d.grad = None

print(f'Result: y = {a.item()} + {b.item()} * x + {c.item()} * x ** 2 + {d.item()} * x ** 3')
# Out:
# 99 tensor(6821.1689, grad_fn=<SumBackward0>)
# 199 tensor(4513.9409, grad_fn=<SumBackward0>)
# 299 tensor(2988.1538, grad_fn=<SumBackward0>)
# 399 tensor(1979.1328, grad_fn=<SumBackward0>)
# 499 tensor(1311.8506, grad_fn=<SumBackward0>)
# 599 tensor(870.5627, grad_fn=<SumBackward0>)
# 699 tensor(578.7275, grad_fn=<SumBackward0>)
# 799 tensor(385.7277, grad_fn=<SumBackward0>)
# 899 tensor(258.0901, grad_fn=<SumBackward0>)
# 999 tensor(173.6778, grad_fn=<SumBackward0>)
# 1099 tensor(117.8517, grad_fn=<SumBackward0>)
# 1199 tensor(80.9306, grad_fn=<SumBackward0>)
# 1299 tensor(56.5123, grad_fn=<SumBackward0>)
# 1399 tensor(40.3628, grad_fn=<SumBackward0>)
# 1499 tensor(29.6817, grad_fn=<SumBackward0>)
# 1599 tensor(22.6174, grad_fn=<SumBackward0>)
# 1699 tensor(17.9451, grad_fn=<SumBackward0>)
# 1799 tensor(14.8548, grad_fn=<SumBackward0>)
# 1899 tensor(12.8108, grad_fn=<SumBackward0>)
# 1999 tensor(11.4589, grad_fn=<SumBackward0>)
# 2099 tensor(10.5646, grad_fn=<SumBackward0>)
# 2199 tensor(9.9731, grad_fn=<SumBackward0>)
# 2299 tensor(9.5819, grad_fn=<SumBackward0>)
# 2399 tensor(9.3231, grad_fn=<SumBackward0>)
# 2499 tensor(9.1519, grad_fn=<SumBackward0>)
# 2599 tensor(9.0386, grad_fn=<SumBackward0>)
# 2699 tensor(8.9637, grad_fn=<SumBackward0>)
# 2799 tensor(8.9141, grad_fn=<SumBackward0>)
# 2899 tensor(8.8813, grad_fn=<SumBackward0>)
# 2999 tensor(8.8596, grad_fn=<SumBackward0>)
# 3099 tensor(8.8453, grad_fn=<SumBackward0>)
# 3199 tensor(8.8358, grad_fn=<SumBackward0>)
# 3299 tensor(8.8295, grad_fn=<SumBackward0>)
# 3399 tensor(8.8253, grad_fn=<SumBackward0>)
# 3499 tensor(8.8226, grad_fn=<SumBackward0>)
# 3599 tensor(8.8207, grad_fn=<SumBackward0>)
# 3699 tensor(8.8195, grad_fn=<SumBackward0>)
# 3799 tensor(8.8187, grad_fn=<SumBackward0>)
# 3899 tensor(8.8182, grad_fn=<SumBackward0>)
# 3999 tensor(8.8179, grad_fn=<SumBackward0>)
# 4099 tensor(8.8176, grad_fn=<SumBackward0>)
# 4199 tensor(8.8175, grad_fn=<SumBackward0>)
# 4299 tensor(8.8174, grad_fn=<SumBackward0>)
# 4399 tensor(8.8173, grad_fn=<SumBackward0>)
# 4499 tensor(8.8173, grad_fn=<SumBackward0>)
# 4599 tensor(8.8172, grad_fn=<SumBackward0>)
# 4699 tensor(8.8172, grad_fn=<SumBackward0>)
# 4799 tensor(8.8172, grad_fn=<SumBackward0>)
# 4899 tensor(8.8172, grad_fn=<SumBackward0>)
# 4999 tensor(8.8172, grad_fn=<SumBackward0>)
# 5099 tensor(8.8172, grad_fn=<SumBackward0>)
# 5199 tensor(8.8172, grad_fn=<SumBackward0>)
# 5299 tensor(8.8172, grad_fn=<SumBackward0>)
# 5399 tensor(8.8172, grad_fn=<SumBackward0>)
# 5499 tensor(8.8172, grad_fn=<SumBackward0>)
# 5599 tensor(8.8172, grad_fn=<SumBackward0>)
# 5699 tensor(8.8172, grad_fn=<SumBackward0>)
# 5799 tensor(8.8172, grad_fn=<SumBackward0>)
# 5899 tensor(8.8172, grad_fn=<SumBackward0>)
# 5999 tensor(8.8172, grad_fn=<SumBackward0>)
# 6099 tensor(8.8172, grad_fn=<SumBackward0>)
# 6199 tensor(8.8172, grad_fn=<SumBackward0>)
# 6299 tensor(8.8172, grad_fn=<SumBackward0>)
# 6399 tensor(8.8172, grad_fn=<SumBackward0>)
# 6499 tensor(8.8172, grad_fn=<SumBackward0>)
# 6599 tensor(8.8172, grad_fn=<SumBackward0>)
# 6699 tensor(8.8172, grad_fn=<SumBackward0>)
# 6799 tensor(8.8172, grad_fn=<SumBackward0>)
# 6899 tensor(8.8172, grad_fn=<SumBackward0>)
# 6999 tensor(8.8172, grad_fn=<SumBackward0>)
# 7099 tensor(8.8172, grad_fn=<SumBackward0>)
# 7199 tensor(8.8172, grad_fn=<SumBackward0>)
# 7299 tensor(8.8172, grad_fn=<SumBackward0>)
# 7399 tensor(8.8172, grad_fn=<SumBackward0>)
# 7499 tensor(8.8172, grad_fn=<SumBackward0>)
# 7599 tensor(8.8172, grad_fn=<SumBackward0>)
# 7699 tensor(8.8172, grad_fn=<SumBackward0>)
# 7799 tensor(8.8172, grad_fn=<SumBackward0>)
# 7899 tensor(8.8172, grad_fn=<SumBackward0>)
# 7999 tensor(8.8172, grad_fn=<SumBackward0>)
# 8099 tensor(8.8172, grad_fn=<SumBackward0>)
# 8199 tensor(8.8172, grad_fn=<SumBackward0>)
# 8299 tensor(8.8172, grad_fn=<SumBackward0>)
# 8399 tensor(8.8172, grad_fn=<SumBackward0>)
# 8499 tensor(8.8172, grad_fn=<SumBackward0>)
# 8599 tensor(8.8172, grad_fn=<SumBackward0>)
# 8699 tensor(8.8172, grad_fn=<SumBackward0>)
# 8799 tensor(8.8172, grad_fn=<SumBackward0>)
# 8899 tensor(8.8172, grad_fn=<SumBackward0>)
# 8999 tensor(8.8172, grad_fn=<SumBackward0>)
# 9099 tensor(8.8172, grad_fn=<SumBackward0>)
# 9199 tensor(8.8172, grad_fn=<SumBackward0>)
# 9299 tensor(8.8172, grad_fn=<SumBackward0>)
# 9399 tensor(8.8172, grad_fn=<SumBackward0>)
# 9499 tensor(8.8172, grad_fn=<SumBackward0>)
# 9599 tensor(8.8172, grad_fn=<SumBackward0>)
# 9699 tensor(8.8172, grad_fn=<SumBackward0>)
# 9799 tensor(8.8172, grad_fn=<SumBackward0>)
# 9899 tensor(8.8172, grad_fn=<SumBackward0>)
# 9999 tensor(8.8172, grad_fn=<SumBackward0>)
# 10099 tensor(8.8172, grad_fn=<SumBackward0>)
# 10199 tensor(8.8172, grad_fn=<SumBackward0>)
# 10299 tensor(8.8172, grad_fn=<SumBackward0>)
# 10399 tensor(8.8172, grad_fn=<SumBackward0>)
# 10499 tensor(8.8172, grad_fn=<SumBackward0>)
# 10599 tensor(8.8172, grad_fn=<SumBackward0>)
# 10699 tensor(8.8172, grad_fn=<SumBackward0>)
# 10799 tensor(8.8172, grad_fn=<SumBackward0>)
# 10899 tensor(8.8172, grad_fn=<SumBackward0>)
# 10999 tensor(8.8172, grad_fn=<SumBackward0>)
# 11099 tensor(8.8172, grad_fn=<SumBackward0>)
# 11199 tensor(8.8172, grad_fn=<SumBackward0>)
# 11299 tensor(8.8172, grad_fn=<SumBackward0>)
# 11399 tensor(8.8172, grad_fn=<SumBackward0>)
# 11499 tensor(8.8172, grad_fn=<SumBackward0>)
# 11599 tensor(8.8172, grad_fn=<SumBackward0>)
# 11699 tensor(8.8172, grad_fn=<SumBackward0>)
# 11799 tensor(8.8172, grad_fn=<SumBackward0>)
# 11899 tensor(8.8172, grad_fn=<SumBackward0>)
# 11999 tensor(8.8172, grad_fn=<SumBackward0>)
# 12099 tensor(8.8172, grad_fn=<SumBackward0>)
# 12199 tensor(8.8172, grad_fn=<SumBackward0>)
# 12299 tensor(8.8172, grad_fn=<SumBackward0>)
# 12399 tensor(8.8172, grad_fn=<SumBackward0>)
# 12499 tensor(8.8172, grad_fn=<SumBackward0>)
# 12599 tensor(8.8172, grad_fn=<SumBackward0>)
# 12699 tensor(8.8172, grad_fn=<SumBackward0>)
# 12799 tensor(8.8172, grad_fn=<SumBackward0>)
# 12899 tensor(8.8172, grad_fn=<SumBackward0>)
# 12999 tensor(8.8172, grad_fn=<SumBackward0>)
# 13099 tensor(8.8172, grad_fn=<SumBackward0>)
# 13199 tensor(8.8172, grad_fn=<SumBackward0>)
# 13299 tensor(8.8172, grad_fn=<SumBackward0>)
# 13399 tensor(8.8172, grad_fn=<SumBackward0>)
# 13499 tensor(8.8172, grad_fn=<SumBackward0>)
# 13599 tensor(8.8172, grad_fn=<SumBackward0>)
# 13699 tensor(8.8172, grad_fn=<SumBackward0>)
# 13799 tensor(8.8172, grad_fn=<SumBackward0>)
# 13899 tensor(8.8172, grad_fn=<SumBackward0>)
# 13999 tensor(8.8172, grad_fn=<SumBackward0>)
# 14099 tensor(8.8172, grad_fn=<SumBackward0>)
# 14199 tensor(8.8172, grad_fn=<SumBackward0>)
# 14299 tensor(8.8172, grad_fn=<SumBackward0>)
# 14399 tensor(8.8172, grad_fn=<SumBackward0>)
# 14499 tensor(8.8172, grad_fn=<SumBackward0>)
# 14599 tensor(8.8172, grad_fn=<SumBackward0>)
# 14699 tensor(8.8172, grad_fn=<SumBackward0>)
# 14799 tensor(8.8172, grad_fn=<SumBackward0>)
# 14899 tensor(8.8172, grad_fn=<SumBackward0>)
# 14999 tensor(8.8172, grad_fn=<SumBackward0>)
# 15099 tensor(8.8172, grad_fn=<SumBackward0>)
# 15199 tensor(8.8172, grad_fn=<SumBackward0>)
# 15299 tensor(8.8172, grad_fn=<SumBackward0>)
# 15399 tensor(8.8172, grad_fn=<SumBackward0>)
# 15499 tensor(8.8172, grad_fn=<SumBackward0>)
# 15599 tensor(8.8172, grad_fn=<SumBackward0>)
# 15699 tensor(8.8172, grad_fn=<SumBackward0>)
# 15799 tensor(8.8172, grad_fn=<SumBackward0>)
# 15899 tensor(8.8172, grad_fn=<SumBackward0>)
# 15999 tensor(8.8172, grad_fn=<SumBackward0>)
# 16099 tensor(8.8172, grad_fn=<SumBackward0>)
# 16199 tensor(8.8172, grad_fn=<SumBackward0>)
# 16299 tensor(8.8172, grad_fn=<SumBackward0>)
# 16399 tensor(8.8172, grad_fn=<SumBackward0>)
# 16499 tensor(8.8172, grad_fn=<SumBackward0>)
# 16599 tensor(8.8172, grad_fn=<SumBackward0>)
# 16699 tensor(8.8172, grad_fn=<SumBackward0>)
# 16799 tensor(8.8172, grad_fn=<SumBackward0>)
# 16899 tensor(8.8172, grad_fn=<SumBackward0>)
# 16999 tensor(8.8172, grad_fn=<SumBackward0>)
# 17099 tensor(8.8172, grad_fn=<SumBackward0>)
# 17199 tensor(8.8172, grad_fn=<SumBackward0>)
# 17299 tensor(8.8172, grad_fn=<SumBackward0>)
# 17399 tensor(8.8172, grad_fn=<SumBackward0>)
# 17499 tensor(8.8172, grad_fn=<SumBackward0>)
# 17599 tensor(8.8172, grad_fn=<SumBackward0>)
# 17699 tensor(8.8172, grad_fn=<SumBackward0>)
# 17799 tensor(8.8172, grad_fn=<SumBackward0>)
# 17899 tensor(8.8172, grad_fn=<SumBackward0>)
# 17999 tensor(8.8172, grad_fn=<SumBackward0>)
# 18099 tensor(8.8172, grad_fn=<SumBackward0>)
# 18199 tensor(8.8172, grad_fn=<SumBackward0>)
# 18299 tensor(8.8172, grad_fn=<SumBackward0>)
# 18399 tensor(8.8172, grad_fn=<SumBackward0>)
# 18499 tensor(8.8172, grad_fn=<SumBackward0>)
# 18599 tensor(8.8172, grad_fn=<SumBackward0>)
# 18699 tensor(8.8172, grad_fn=<SumBackward0>)
# 18799 tensor(8.8172, grad_fn=<SumBackward0>)
# 18899 tensor(8.8172, grad_fn=<SumBackward0>)
# 18999 tensor(8.8172, grad_fn=<SumBackward0>)
# 19099 tensor(8.8172, grad_fn=<SumBackward0>)
# 19199 tensor(8.8172, grad_fn=<SumBackward0>)
# 19299 tensor(8.8172, grad_fn=<SumBackward0>)
# 19399 tensor(8.8172, grad_fn=<SumBackward0>)
# 19499 tensor(8.8172, grad_fn=<SumBackward0>)
# 19599 tensor(8.8172, grad_fn=<SumBackward0>)
# 19699 tensor(8.8172, grad_fn=<SumBackward0>)
# 19799 tensor(8.8172, grad_fn=<SumBackward0>)
# 19899 tensor(8.8172, grad_fn=<SumBackward0>)
# 19999 tensor(8.8172, grad_fn=<SumBackward0>)
# Result: y = 6.845105371411364e-09 + 0.8567265868186951 * x + -1.1152383017076772e-08 * x ** 2 + -0.09332836419343948 * x ** 3

# %%
print(a + b * math.pi + c * math.pi * math.pi + d * math.pi * math.pi * math.pi)
# Out:
# tensor(-0.2023, grad_fn=<AddBackward0>)
